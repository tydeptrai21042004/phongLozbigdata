# %%
# !git clone https://github.com/tydeptrai21042004/phongLozbigdata
# Out:
# Cloning into 'phongLozbigdata'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 19 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (19/19), 29.43 KiB | 1.96 MiB/s, done.

# %%
# !pwd
# !ls
# Out:
# /content
# phongLozbigdata  sample_data

# %%
# %cd phongLozbigdata
# Out:
# /content/phongLozbigdata

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.5/246.5 kB 29.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 120.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 105.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 96.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 22.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.4/755.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 75.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 81.7 MB/s eta 0:00:00
# ...

# %%
# !mkdir -p data/raw
# !mkdir -p data/processed
# !mkdir -p models/saved
# !mkdir -p output/plots

# %%
# !wget -O data/raw/vmtable.csv.gz "https://azurepublicdatasettraces.blob.core.windows.net/azurepublicdatasetv2/trace_data/vmtable/vmtable.csv.gz"

# !wget -O data/raw/vm_cpu_readings-file-1-of-195.csv.gz "https://azurepublicdatasettraces.blob.core.windows.net/azurepublicdatasetv2/trace_data/vm_cpu_readings/vm_cpu_readings-file-1-of-195.csv.gz"

# !wget -O data/raw/vm_cpu_readings-file-2-of-195.csv.gz "https://azurepublicdatasettraces.blob.core.windows.net/azurepublicdatasetv2/trace_data/vm_cpu_readings/vm_cpu_readings-file-2-of-195.csv.gz"
# Out:
# --2026-04-03 16:24:19--  https://azurepublicdatasettraces.blob.core.windows.net/azurepublicdatasetv2/trace_data/vmtable/vmtable.csv.gz
# Resolving azurepublicdatasettraces.blob.core.windows.net (azurepublicdatasettraces.blob.core.windows.net)... 52.239.236.228
# Connecting to azurepublicdatasettraces.blob.core.windows.net (azurepublicdatasettraces.blob.core.windows.net)|52.239.236.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 437594496 (417M) [application/octet-stream]
# Saving to: ‘data/raw/vmtable.csv.gz’
#
# data/raw/vmtable.cs 100%[===================>] 417.32M  56.3MB/s    in 7.7s
#
# 2026-04-03 16:24:27 (53.9 MB/s) - ‘data/raw/vmtable.csv.gz’ saved [437594496/437594496]
#
# --2026-04-03 16:24:27--  https://azurepublicdatasettraces.blob.core.windows.net/azurepublicdatasetv2/trace_data/vm_cpu_readings/vm_cpu_readings-file-1-of-195.csv.gz
# ...

# %%
# !ls -lh data/raw
# Out:
# total 2.1G
# -rw-r--r-- 1 root root 817M Jun 26  2024 vm_cpu_readings-file-1-of-195.csv.gz
# -rw-r--r-- 1 root root 818M Jun 26  2024 vm_cpu_readings-file-2-of-195.csv.gz
# -rw-r--r-- 1 root root 418M Jun 26  2024 vmtable.csv.gz

# %%
# !python ml_models/lstm_models.py
# Out:
# INFO:__main__:Using device: cuda
# INFO:__main__:Found 2 CPU file(s). Reading until 50 unique timestamps...
# INFO:__main__:Scanning vm_cpu_readings-file-1-of-195.csv.gz...
# INFO:__main__:Scanning vm_cpu_readings-file-2-of-195.csv.gz...
# INFO:__main__:Global aggregated time-series length: 50
# INFO:__main__:
# ...
# INFO:__main__:  Training LSTM Autoencoder
# INFO:__main__:==================================================
# INFO:__main__:Preparing sequences for LSTM Autoencoder...
# INFO:__main__:  Sequences: 41
# INFO:__main__:  Sequence length: 10
# INFO:__main__:  Features: 4
# INFO:__main__:Training LSTM Autoencoder for 10 epochs...
# INFO:__main__:  Epoch 1/10 | Loss: 0.384413
# INFO:__main__:  Epoch 5/10 | Loss: 0.299246
# INFO:__main__:  Epoch 10/10 | Loss: 0.200686
# INFO:__main__:  Threshold (p95): 0.287006
# INFO:__main__:LSTM Autoencoder saved to /content/phongLozbigdata/models/saved/lstm_autoencoder/
# INFO:__main__:
# ...
# INFO:__main__:  Training LSTM Forecaster (CPU)
# ...
